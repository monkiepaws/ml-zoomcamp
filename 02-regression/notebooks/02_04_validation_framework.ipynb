# %% [markdown]
# # Module 2.4 Setting up the validation framework

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load cleaned data

# %%
df = pd.read_csv('02-regression/notebooks/data_cleaned.csv')
df.sample(5)
# Out:
#            make        model  year                engine_fuel_type  engine_hp  \
# 3381      mazda         cx-7  2010  premium_unleaded_(recommended)      244.0
# 3213   cadillac  cts-v_coupe  2014     premium_unleaded_(required)      556.0
# 11548     scion           xb  2015                regular_unleaded      158.0
# 3352      mazda         cx-5  2014                regular_unleaded      155.0
# 1666    hyundai        azera  2016                regular_unleaded      293.0
#
#        engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 3381                4.0         automatic    all_wheel_drive              4.0
# 3213                8.0            manual   rear_wheel_drive              2.0
# 11548               4.0         automatic  front_wheel_drive              4.0
# 3352                4.0         automatic    all_wheel_drive              4.0
# 1666                6.0         automatic  front_wheel_drive              4.0
#
#                              market_category vehicle_size vehicle_style  \
# 3381                               crossover      midsize       4dr_suv
# 3213   factory_tuner,luxury,high-performance      midsize         coupe
# 11548                                    NaN      compact         wagon
# 3352                               crossover      midsize       4dr_suv
# 1666                             performance      midsize         sedan
#
#        highway_mpg  city_mpg  popularity   msrp
# 3381            23        17         586  27650
# 3213            19        14        1624  63600
# 11548           28        22         105  18070
# 3352            31        25         586  24045
# 1666            29        20        1439  34100

# %% [markdown]
# ## Splitting data
# We want to split data to isolate training, validation, and testing (e.g. 60/20/20 splits).

# %%
# Number of records in the dataset
n = len(df)
print(f"Number of records: {n}")

# 20% of the total number of records
print(f"20% of total records: {n * 0.2}\n")

# Calculate size of each data set split
n_val = int(n * 0.2)
n_test = int(n * 0.2)
n_train = n - n_val - n_test
print(f"Training set size: {n_train}")
print(f"Validation set size: {n_val}")
print(f"Test set size: {n_test}")
print(f"\nTotal: {n_train + n_val + n_test}")
# Out:
# Number of records: 11914
# 20% of total records: 2382.8
#
# Training set size: 7150
# Validation set size: 2382
# Test set size: 2382
#
# Total: 11914

# %%
# We need to shuffle the data frame so that the split sets are randomly selected
# First create a range of numbers from 0 to n-1
idx = np.arange(n)
np.random.seed(42)  # Set the random seed for reproducibility
np.random.shuffle(idx)  # Shuffle the indices

idx[:5]
# Out:
# array([3995, 7474, 7300, 3148,  747])

# %%
# Create the sub sets
df_train = df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train:n_train + n_val]]
df_test = df.iloc[idx[n_train + n_val:]]

# %%
df_train.head(8)
# Out:
#             make     model  year                engine_fuel_type  engine_hp  \
# 3995         gmc  envoy_xl  2005                regular_unleaded      275.0
# 7474  volkswagen    passat  2016                regular_unleaded      170.0
# 7300       honda   odyssey  2016                regular_unleaded      248.0
# 3148   chevrolet     cruze  2015                regular_unleaded      138.0
# 747        volvo       740  1991                regular_unleaded      162.0
# 4048      suzuki   equator  2012                regular_unleaded      152.0
# 4759        ford      flex  2016  premium_unleaded_(recommended)      365.0
# 6423       acura    legend  1994                regular_unleaded      230.0
#
#       engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 3995               6.0         automatic   rear_wheel_drive              4.0
# 7474               4.0         automatic  front_wheel_drive              4.0
# 7300               6.0         automatic  front_wheel_drive              4.0
# 3148               4.0            manual  front_wheel_drive              4.0
# 747                4.0         automatic   rear_wheel_drive              4.0
# 4048               4.0            manual   rear_wheel_drive              4.0
# 4759               6.0         automatic    all_wheel_drive              4.0
# 6423               6.0            manual  front_wheel_drive              2.0
#
#          market_category vehicle_size        vehicle_style  highway_mpg  \
# 3995                 NaN        large              4dr_suv           18
# 7474                 NaN      midsize                sedan           38
# 7300                 NaN        large    passenger_minivan           28
# 3148                 NaN      midsize                sedan           36
# 747   luxury,performance      midsize                sedan           20
# 4048                 NaN      compact  extended_cab_pickup           23
# 4759           crossover        large                wagon           21
# 6423  luxury,performance      midsize                coupe           24
#
#       city_mpg  popularity   msrp
# 3995        13         549  29695
# 7474        25         873  30495
# 7300        19        2202  37650
# 3148        25        1385  16170
# 747         17         870   2000
# 4048        19         481  19299
# 4759        15        5657  42600
# 6423        16         204   2384

# %%
len(df_train), len(df_val), len(df_test), len(
    df_train) + len(df_val) + len(df_test)
# Out:
# (7150, 2382, 2382, 11914)

# %%
# Reset the indices as we don't need the original indices anymore
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
df_train.head(8)
# Out:
#          make     model  year                engine_fuel_type  engine_hp  \
# 0         gmc  envoy_xl  2005                regular_unleaded      275.0
# 1  volkswagen    passat  2016                regular_unleaded      170.0
# 2       honda   odyssey  2016                regular_unleaded      248.0
# 3   chevrolet     cruze  2015                regular_unleaded      138.0
# 4       volvo       740  1991                regular_unleaded      162.0
# 5      suzuki   equator  2012                regular_unleaded      152.0
# 6        ford      flex  2016  premium_unleaded_(recommended)      365.0
# 7       acura    legend  1994                regular_unleaded      230.0
#
#    engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 0               6.0         automatic   rear_wheel_drive              4.0
# 1               4.0         automatic  front_wheel_drive              4.0
# 2               6.0         automatic  front_wheel_drive              4.0
# 3               4.0            manual  front_wheel_drive              4.0
# 4               4.0         automatic   rear_wheel_drive              4.0
# 5               4.0            manual   rear_wheel_drive              4.0
# 6               6.0         automatic    all_wheel_drive              4.0
# 7               6.0            manual  front_wheel_drive              2.0
#
#       market_category vehicle_size        vehicle_style  highway_mpg  \
# 0                 NaN        large              4dr_suv           18
# 1                 NaN      midsize                sedan           38
# 2                 NaN        large    passenger_minivan           28
# 3                 NaN      midsize                sedan           36
# 4  luxury,performance      midsize                sedan           20
# 5                 NaN      compact  extended_cab_pickup           23
# 6           crossover        large                wagon           21
# 7  luxury,performance      midsize                coupe           24
#
#    city_mpg  popularity   msrp
# 0        13         549  29695
# 1        25         873  30495
# 2        19        2202  37650
# 3        25        1385  16170
# 4        17         870   2000
# 5        19         481  19299
# 6        15        5657  42600
# 7        16         204   2384

# %%
# Normalise the target variable
y_train = np.log1p(df_train.msrp.values)
y_val = np.log1p(df_val.msrp.values)
y_test = np.log1p(df_test.msrp.values)

# Print the first 5 values of each target variable
print("y_train:", y_train[:5])
print("y_val:", y_val[:5])
print("y_test:", y_test[:5])
# Out:
# y_train: [10.29876764 10.32535081 10.53611479  9.69097479  7.60140233]
# y_val: [10.35840927 10.75344616 10.09352923  9.99016971 10.42141788]
# y_test: [10.28622977 10.14155912 10.50687413 10.12246243 10.8277663 ]

# %%
# We don't need the target variable in the data frames anymore
df_train = df_train.drop('msrp', axis=1)
df_val = df_val.drop('msrp', axis=1)
df_test = df_test.drop('msrp', axis=1)

# %%
print((df_train.columns == 'msrp').sum())
# Out:
# 0

# %% [markdown]
# ## Export data sets

# %%
df_train.to_csv('02-regression/notebooks/data_train.csv', index=False)
df_val.to_csv('02-regression/notebooks/data_val.csv', index=False)
df_test.to_csv('02-regression/notebooks/data_test.csv', index=False)
